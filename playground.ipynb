# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from glob import glob

# %%
import lanelines
import newlanespipeline 

from compgraph import CompGraph, CompGraphRunner
import nxpd
nxpd.nxpdParams['show'] = 'ipynb'

# %%
TEST_IM_DIR = 'test_images'

# %%
images = [cv2.imread(f) for f in glob(TEST_IM_DIR + '/*.jpg')]

# %%
cg = newlanespipeline.computational_graph

cg_params = {
    'x_from': 518,
    'x_to': 590,
    'y_lim': 460,
    'left_offset': 214,
    'right_offset': 202
}

runner = CompGraphRunner(cg, frozen_tokens=cg_params)
nxpd.draw(runner.token_manager.to_networkx())
